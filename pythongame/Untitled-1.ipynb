# %%
import os 
import pandas as pd
import numpy as np
os.getcwd()
# Out:
# '/Users/fyenne/Downloads/booooks/semester5/pythonAAE/pythongame'

# %%
import pygame
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-671b35b41eba> in <module>
# ----> 1 import pygame
#
# ModuleNotFoundError: No module named 'pygame'

# %%
pip install -i https://pypi.tuna.tsinghua.edu.cn/simple pygame
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/c7/b8/06e02c7cca7aec915839927a9aa19f749ac17a3d2bb2610b945d2de0aa96/pygame-2.0.1.tar.gz (5.5 MB)
#     ERROR: Command errored out with exit status 1:
# ...
