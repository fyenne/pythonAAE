# %%
# !pip install mxnet==1.7.0.post1
# Out:
# Looking in indexes: https://mirrors.ustc.edu.cn/pypi/web/simple
# ...
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/56/1c/130451251bd420e6784a0daf0a3a8f932c03616d209e394069d8ae91e55d/mxnet-1.7.0.post1-py2.py3-none-win_amd64.whl (33.0 MB)
# ...
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/b7/6f/24647f014eef9b67a24adfcbcd4f4928349b4a0f8393b3d7fe648d4d2de3/numpy-1.16.6.zip (5.1 MB)
# ...
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/53/39/4ab213673844e0c004bed8a0781a0721a3f6bb23eb8854ee75c236428892/graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# ...
#   Running setup.py clean for numpy
# Failed to build numpy
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#   ERROR: Command errored out with exit status 1:
# ...

# %%
import pandas as pd
# Out:
# D:\miniconda_dependent\miniconda\envs\siming\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# D:\miniconda_dependent\miniconda\envs\siming\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# D:\miniconda_dependent\miniconda\envs\siming\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df65=pd.read_csv('D:\\myboooks_from_mac\\pythonAAE\\work2\\bms_all_ap.csv')
df65.head()
# Out:
#              jjcode                                            content  \
# 0  V158627042500001  场地仓储费税率：6.0000%100.0000%操作入库费税率：6.0000%100.000...
# 1  V158627042500001  场地仓储费税率：6.0000%100.0000%操作入库费税率：6.0000%100.000...
# 2  V158627042500001  场地仓储费税率：6.0000%100.0000%操作入库费税率：6.0000%100.000...
# 3  V158627042500001  场地仓储费税率：6.0000%100.0000%操作入库费税率：6.0000%100.000...
# 4  V158627042500001  场地仓储费税率：6.0000%100.0000%操作入库费税率：6.0000%100.000...
#
#                 计价名称         客户ID 客户名称         ID_x               项目名称  \
# 0  BMW ConDC Billing  C8389775201  BMW  P8410982116  Shanghai Yangshan
# 1  BMW ConDC Billing  C8389775201  BMW  P8410982116  Shanghai Yangshan
# 2  BMW ConDC Billing  C8389775201  BMW  P8410982116  Shanghai Yangshan
# 3  BMW ConDC Billing  C8389775201  BMW  P8410982116  Shanghai Yangshan
# 4  BMW ConDC Billing  C8389775201  BMW  P8410982116  Shanghai Yangshan
#
#          生效日期        失效日期 variable  ...        ID_y 所属行业        结算编码  结算周期  \
# ...

# %%
df65[df65['ID_y'] =="SFELCSHMHS"| "SKFCNSHMFS"| "OLYXXSHKQS"|"ASMLXBJKCS"|"ASMLXSHZCS"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-9540c1c4dea6> in <module>
# ----> 1 df65[df65['ID_y'] =="SFELCSHMHS"| "SKFCNSHMFS"| "OLYXXSHTRT"|"ASMLXBJKCS"|"ASMLXSHZCS"]
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'

# %%
li = ["SFELCSHMHS", "SKFCNSHMFS", "OLYXXSHTRT","ASMLXBJKCS","ASMLXSHZCS"]

# %%
df65[df65[u'ID_y'].isin(li)].to_csv('D:\\myboooks_from_mac\\pythonAAE\\work2\\data_65.csv', encoding = 'utf_8_sig')

# %%
df652=pd.read_csv('D:\\myboooks_from_mac\\pythonAAE\\work2\\bms_longer0601.csv')
df652.head()
# Out:
#              jjcode                                            content  \
# 0  V158564994100001  ���زִ���˰�ʣ�6.0000%100.0000%�칫��ʩ��˰�ʣ�6.0000%...
# 1  V158588338500001  ���زִ���˰�ʣ�6.0000%100.0000%�������ڲ�����˰�ʣ�6...
# 2  V158588382400001  ���زִ���˰�ʣ�6.0000%100.0000%��������˰�ʣ�6.0000...
# 3  V158588646600001  ���زִ���˰�ʣ�6.0000%100.0000%��������˰�ʣ�6.0000...
# 4  V158589474500001  ���زִ���˰�ʣ�6.0000%100.0000%��������˰�ʣ�6.0000...
#
#          �Ƽ�����        �ͻ�ID   �ͻ�����        ��ĿID               ��Ŀ����  \
# 0    20200410�Ƽ�  C8389773001      ASML  P8410982114   Xiamen N Xiangan Rd
# 1  ������L3L4�ֿ�  C8389781501  ERICSSON  P8410982206    Guangzhou Huang Pu
# 2    20200410�Ƽ�  C8389773001      ASML  P8410982110   Nanjing Lanhua Road
# 3  2020.04.10�Ƽ�  C8389773001      ASML  P8410982109      Beijing Kechuang
# 4    20200410�Ƽ�  C8389773001      ASML  P8410982111  Shanghai Zuchong Zhi
#
#       ��Ч����      ʧЧ���� variable value
# 0  2020-04-01  2022-01-31     ����  ����
# ...

# %%
np.arange(1,3)
# Out:
# array([1, 2])
